# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
import seaborn as sns
from statsmodels.tsa import ar_model
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import numpy as np
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM
from keras.callbacks import EarlyStopping
from keras.layers import Dropout, TimeDistributed

# %%
df = pd.read_csv('temp.csv')

# %%
df.plot(figsize=(15,10))

# %%
df.shape
# Out:
# (3650, 2)

# %%
train = df[0:3500].copy()
test = df[3500:].copy()
test = test.reset_index()

# %% [markdown]
# ## Create an LSTM model

# %% [markdown]
# ## Step 1: create input model

# %%
def create_features(sequence, lag):
    X, y = [], []
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + lag
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
lag = 60
# split into features
X, y = create_features(train.Temp, lag)
val_X, val_y = create_features(test.Temp, lag)
for i in range(len(X)):
    print(X[i], y[i])
# Out:
# [20.7 17.9 18.8 14.6 15.8 15.8 15.8 17.4 21.8 20.  16.2 13.3 16.7 21.5
#  25.  20.7 20.6 24.8 17.7 15.5 18.2 12.1 14.4 16.  16.5 18.7 19.4 17.2
#  15.5 15.1 15.4 15.3 18.8 21.9 19.9 16.6 16.8 14.6 17.1 25.  15.  13.7
#  13.9 18.3 22.  22.1 21.2 18.4 16.6 16.1 15.7 16.6 16.5 14.4 14.4 18.5
#  16.9 17.5 21.2 17.8] 18.6
# [17.9 18.8 14.6 15.8 15.8 15.8 17.4 21.8 20.  16.2 13.3 16.7 21.5 25.
#  20.7 20.6 24.8 17.7 15.5 18.2 12.1 14.4 16.  16.5 18.7 19.4 17.2 15.5
#  15.1 15.4 15.3 18.8 21.9 19.9 16.6 16.8 14.6 17.1 25.  15.  13.7 13.9
#  18.3 22.  22.1 21.2 18.4 16.6 16.1 15.7 16.6 16.5 14.4 14.4 18.5 16.9
#  17.5 21.2 17.8 18.6] 17.0
# [18.8 14.6 15.8 15.8 15.8 17.4 21.8 20.  16.2 13.3 16.7 21.5 25.  20.7
#  20.6 24.8 17.7 15.5 18.2 12.1 14.4 16.  16.5 18.7 19.4 17.2 15.5 15.1
#  15.4 15.3 18.8 21.9 19.9 16.6 16.8 14.6 17.1 25.  15.  13.7 13.9 18.3
#  22.  22.1 21.2 18.4 16.6 16.1 15.7 16.6 16.5 14.4 14.4 18.5 16.9 17.5
#  21.2 17.8 18.6 17. ] 16.0
# ...

# %%
# define model
n_features = 1
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(lag, n_features),  return_sequences=True))
model.add(TimeDistributed(Dense(1)))
model.compile(optimizer='adam', loss='mse')

# %%
X = X.reshape((X.shape[0], X.shape[1], n_features))
# val_X = val_X.reshape((val_X.shape[0], val_X.shape[1], n_features))

# %%
X.shape
# Out:
# (3440, 60, 1)

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# %%
hist = model.fit(X, y, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 108/108 [==============================] - 5s 51ms/step - loss: 23.8274
# Epoch 2/200
# 108/108 [==============================] - 6s 58ms/step - loss: 13.5221
# Epoch 3/200
# 108/108 [==============================] - 5s 46ms/step - loss: 12.5476
# Epoch 4/200
# 108/108 [==============================] - 6s 52ms/step - loss: 11.7838
# Epoch 5/200
# 108/108 [==============================] - 6s 60ms/step - loss: 11.3120
# Epoch 6/200
# 108/108 [==============================] - 6s 54ms/step - loss: 11.2011
# Epoch 7/200
# 108/108 [==============================] - 6s 53ms/step - loss: 11.0899
# Epoch 8/200
# 108/108 [==============================] - 5s 46ms/step - loss: 11.0715
# Epoch 9/200
# 108/108 [==============================] - 5s 48ms/step - loss: 10.9663
# Epoch 10/200
# 108/108 [==============================] - 6s 53ms/step - loss: 11.2623
# Epoch 11/200
# 108/108 [==============================] - 5s 50ms/step - loss: 11.3307
# Epoch 12/200
# ...

# %%
X[-1]
# Out:
# array([[ 8.3],
#        [ 9.7],
#        [ 9.6],
#        [ 9.8],
#        [10.8],
#        [ 9.2],
#        [ 6.5],
#        [ 8.1],
#        [ 7.3],
#        [ 7.9],
#        [ 6. ],
#        [ 5. ],
#        [ 6.8],
#        [ 9.8]])

# %%
pred = model.predict(X[-1].reshape((1, lag, n_features)))

# %%
def pred_train(X):
    preds = []
    for i in range(0, len(X)):
        X[i].reshape((1, lag, n_features))
        prediction = model.predict(features)[0][0][0]

# %%
def pred_test(n_preds, last_sample):
    preds = []
    features = last_sample.reshape((1, lag, n_features))
    for i in range(0, n_preds):
        prediction = model.predict(features)[0][0][0]
        preds.append(prediction)
        print(features)
        features = np.delete(features, 0, axis=1)
        print(features)
        print(prediction)
        features = np.append(features, [[[prediction]]], axis=1)
    return preds

# %%
preds = pred_test(len(test), X[-1])
# Out:
# [[[ 8.3]
#   [ 9.7]
#   [ 9.6]
#   [ 9.8]
#   [10.8]
#   [ 9.2]
#   [ 6.5]
#   [ 8.1]
#   [ 7.3]
#   [ 7.9]
#   [ 6. ]
#   [ 5. ]
#   [ 6.8]
#   [ 9.8]]]
# [[[ 9.7]
#   [ 9.6]
#   [ 9.8]
#   [10.8]
#   [ 9.2]
#   [ 6.5]
#   [ 8.1]
#   [ 7.3]
#   [ 7.9]
#   [ 6. ]
#   [ 5. ]
#   [ 6.8]
#   [ 9.8]]]
# 9.596117
# [[[ 9.7       ]
#   [ 9.6       ]
#   [ 9.8       ]
#   [10.8       ]
#   [ 9.2       ]
#   [ 6.5       ]
#   [ 8.1       ]
#   [ 7.3       ]
#   [ 7.9       ]
#   [ 6.        ]
#   [ 5.        ]
#   [ 6.8       ]
#   [ 9.8       ]
#   [ 9.59611702]]]
# [[[ 9.6       ]
#   [ 9.8       ]
#   [10.8       ]
#   [ 9.2       ]
#   [ 6.5       ]
#   [ 8.1       ]
#   [ 7.3       ]
#   [ 7.9       ]
#   [ 6.        ]
#   [ 5.        ]
#   [ 6.8       ]
#   [ 9.8       ]
#   [ 9.59611702]]]
# 10.402407
# [[[ 9.6       ]
#   [ 9.8       ]
#   [10.8       ]
#   [ 9.2       ]
#   [ 6.5       ]
#   [ 8.1       ]
#   [ 7.3       ]
#   [ 7.9       ]
#   [ 6.        ]
#   [ 5.        ]
# ...

# %%
test['pred'] = preds

# %%
test
# Out:
#              Date  Temp       pred
# index
# 3500   1990-08-04   8.6   9.596117
# 3501   1990-08-05  10.6  10.402407
# 3502   1990-08-06   7.8  10.346094
# 3503   1990-08-07   7.7  10.458542
# 3504   1990-08-08   8.6  11.010784
# 3505   1990-08-09   6.5  10.118984
# 3506   1990-08-10   6.9   8.494562
# 3507   1990-08-11   6.4   9.477478
# 3508   1990-08-12   8.5   8.993073
# 3509   1990-08-13   7.8   9.357882
# 3510   1990-08-14   9.3   8.174028
# 3511   1990-08-15   8.4   7.506838
# 3512   1990-08-16   7.8   8.683080
# 3513   1990-08-17   7.4  10.458542
# 3514   1990-08-18   7.7  10.343903
# 3515   1990-08-19   8.9  10.793108
# 3516   1990-08-20   9.7  10.762083
# 3517   1990-08-21   9.9  10.823986
# 3518   1990-08-22   6.1  11.125399
# 3519   1990-08-23   6.6  10.636446
# 3520   1990-08-24   7.6   9.710641
# 3521   1990-08-25   7.4  10.276850
# 3522   1990-08-26   8.0  10.000277
# 3523   1990-08-27   2.1  10.208988
# 3524   1990-08-28   5.9   9.521502
# ...

# %%
test = test.set_index('index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenvs/codequarantine/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-289-fa47d56b8440> in <module>
# ...

# %%
ax = train[3400:].plot(figsize=(15,10))
test.plot(ax=ax)

# %%
test
# Out:
#              Date  Temp       pred
# index
# 3500   1990-08-04   8.6   9.596117
# 3501   1990-08-05  10.6  10.402407
# 3502   1990-08-06   7.8  10.346094
# 3503   1990-08-07   7.7  10.458542
# 3504   1990-08-08   8.6  11.010784
# 3505   1990-08-09   6.5  10.118984
# 3506   1990-08-10   6.9   8.494562
# 3507   1990-08-11   6.4   9.477478
# 3508   1990-08-12   8.5   8.993073
# 3509   1990-08-13   7.8   9.357882
# 3510   1990-08-14   9.3   8.174028
# 3511   1990-08-15   8.4   7.506838
# 3512   1990-08-16   7.8   8.683080
# 3513   1990-08-17   7.4  10.458542
# 3514   1990-08-18   7.7  10.343903
# 3515   1990-08-19   8.9  10.793108
# 3516   1990-08-20   9.7  10.762083
# 3517   1990-08-21   9.9  10.823986
# 3518   1990-08-22   6.1  11.125399
# 3519   1990-08-23   6.6  10.636446
# 3520   1990-08-24   7.6   9.710641
# 3521   1990-08-25   7.4  10.276850
# 3522   1990-08-26   8.0  10.000277
# 3523   1990-08-27   2.1  10.208988
# 3524   1990-08-28   5.9   9.521502
# ...
